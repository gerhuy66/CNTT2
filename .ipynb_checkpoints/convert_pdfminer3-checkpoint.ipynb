# %%
# from pdfminer3.layout import LAParams, LTTextBox
# from pdfminer3.pdfpage import PDFPage
# from pdfminer3.pdfinterp import PDFResourceManager
# from pdfminer3.pdfinterp import PDFPageInterpreter
# from pdfminer3.converter import PDFPageAggregator
# from pdfminer3.converter import TextConverter
from tika import parser
import io
import os
import re
# def pdf_to_text(file):
#     resource_manager = PDFResourceManager()
#     fake_file_handle = io.StringIO()
#     converter = TextConverter(resource_manager, fake_file_handle, laparams=LAParams())
#     page_interpreter = PDFPageInterpreter(resource_manager, converter)
#     with open(file, 'rb') as fh:
#         for page in PDFPage.get_pages(fh,
#                                       caching=True,
#                                       check_extractable=True):
#             page_interpreter.process_page(page)
#         text = fake_file_handle.getvalue()
#     # close open handles
#     converter.close()
#     fake_file_handle.close()
#     return text

# %%
import os
#Read file and Open file
f = os.listdir('pdf')
for f1 in f:
#     txt = pdf_to_text('pdf' + '/' + f1)
    try:
        raw = parser.from_file('pdf' + '/' + f1)
        txtFile = open('txt' + '/' + f1.replace('.pdf','.txt'),'w', encoding="utf8")
        txtFile.write(re.sub(r"\n+", "\n", raw['content']))
        txtFile.close()
    except:
        print(f1)
# Out:
# Business_Analyst_CV_Tran_Hoang_Thai.pdf
# PhanDuyTuan_InternJava.pdf
# vo thanh tung digital marketing.pdf

# %%
raw = parser.from_file('baotamngh.pdf')

# %%
print(raw['content'])
# Out:
# (48) Tâm Nguyễn | LinkedIn
#
#
# 0 notifications total
#
# Skip to search  Skip to main content   Close jump menu
#
# 0 suggestions found.
# Search
#
# Search
#
# Primary Navigation
# new new feed updates notifications
# Home
#
# My Network
#
# Jobs
#
# Messaging
# 48 48 new 48 new notifications. notifications
# Notifications
#
#  Me
#
# Work
# Try Premium Free for 1 Month
#
# Tâm Nguyễn
# Content Writer at 1PAC Vietnam Co., Ltd
#
# Connect
#
#  Message
#
# More…
#
#  Share profile in a message Share Tâm Nguyễn’s profile via message
#
# Message
#
#  Save to PDF Save Tâm Nguyễn’s profile to PDF
#
#  Follow Follow Tâm Nguyễn
#
# file:///feed/?doFeedRefresh=true&nis=true
# file:///feed/
# file:///mynetwork/
# file:///jobs/
# file:///messaging/
# file:///notifications/
# https://www.linkedin.com/premium/products?upsellOrderOrigin=premium_nav_upsell_text&destRedirectURL=https%253A%252F%252Fwww.linkedin.com%252Fin%252Fbaotamngh%252F%253ForiginalSubdomain%253Dvn%2526showPremiumWelcomeBanner%253Dtrue
# file:///company/marketista-chamba/
# file:///in/baotamngh/detail/overlay-view/urn:li:fsd_profileTreasuryMedia:(ACoAAC99v_YBNSeZMXK_tXx4omSho_6i4ey1PiI,1607768367027)/
# file:///company/1pac-vietnam/
# file:///school/371003/?legacySchoolId=371003
# file:///company/rmit-university-vietnam/
# file:///company/rmit-university-vietnam/
# file:///company/ogilvy/
# file:///company/procter-and-gamble/
# file:///company/unilever/
# file:///company/vinamilk/
# file:///company/rmit-university-vietnam/
# file:///company/edelman/
# file:///in/t%25E1%25BA%25A5n-ph%25C3%25A1t-ph%25E1%25BA%25A1m-6a3368180/
# file:///in/nguyen-tran-minh-tien/
# file:///in/dung-nguyen-344260181/
# file:///in/l%25C3%25AA-thi%25E1%25BB%2587n-ti%25E1%25BA%25BFn-a18b9b161/
# file:///in/tuongvy267/
# file:///in/mynguyenhr/
# file:///in/hien-tran-9a282a1b2/
# file:///in/lenhathuylscm/
# file:///in/kh%25C3%25A1nh-linh-%25C4%2591%25E1%25BB%2597-a005401b5/
# file:///in/devcodedao/
#
#
#  Report / Block Report or block Tâm Nguyễn’s profile
#
# Status is offline
#
# Connect
#
#  Message
#
#  More actions
#
#  Share profile in a message Share Tâm Nguyễn’s profile via message
#
# Message
#
#  Save to PDF Save Tâm Nguyễn’s profile to PDF
#
#  Follow Follow Tâm Nguyễn
#
#  Report / Block Report or block Tâm Nguyễn’s profile
#
# Tâm Nguyễn
# 3rd degree connection3rd
#
# Content Writer at 1PAC Vietnam Co., Ltd
# Vietnam
# 65 connections
# Contact info
#
#  1PAC Vietnam Co., Ltd
#
#  RMIT University Vietnam
#
# file:///in/baotamngh/detail/contact-info/
#
#
# People and pages related to Tâm
#
# See all
#
#  Previous   Next
#
# Marketista Chamba - Oportunidades para
# Marketeros y Publicistas
# Page • Marketing & Advertising
# 14,382 followers
#
# Follow
#
# One Minute Briefs Page • Marketing & Advertising
# 16,387 followers
#
# Follow
#
# The Martin Agency Page • Marketing & Advertising
# 39,073 followers
#
# Follow
#
# file:///company/marketista-chamba/
# file:///company/oneminutebriefs/
# file:///company/oneminutebriefs/
# file:///company/themartinagency/
# file:///company/themartinagency/
#
#
# About
# I'm trying to gain technical knowledge and improve my soft skills to become an editorial marketing and communication strategist that transforms the way brands communicate with the audience's approach and colorful ideas. ... see
# more
#
# Featured
#
# Featured
#
# MINIMALISME.pdf
#
# Activity
# 65 followers
#
# Posts Tâm created, shared, or commented on in the last 90 days are displayed here.
#
# See all activity See all activity
#
# Experience
#
# Content Writer
#
# Company Name
#
# 1PAC Vietnam Co., Ltd Contract
#
# Dates Employed Feb 2019 – Present
#
# Employment Duration 2 yrs 3 mos
#
# Location Ho Chi Minh City, Vietnam
#
# To write personal experience sharing articles about Japan as required by Waku Waku project.
#
# file:///in/baotamngh/detail/recent-activity/
#
#
# Education
#
# RMIT University Vietnam
#
# Degree Name Bachelor's degree
#
# Field Of Study Professional Communication
#
# Dates attended or expected graduation 2019 – 2022
#
# Licenses & certifications
#
# Content Battle
#
# Issuing authority RMIT University Vietnam
#
# Volunteer experience
#
# Community Volunteer
#
# Company Name RMIT University Vietnam
#
# Dates volunteered Dec 2019
#
# Volunteer duration 1 mo
#
# Cause Education
#
# ‘RMIT International Festival 2019’
# - Leader of the community for foreign students in the event.
# - Monitored workflow to ensure efficiency.
# - Assisted in branding and developing action programs
#
# Skills & endorsements
#
#
#
# 1. Editing
#
# 2. Content Marketing
#
# 3. Copywriting
#
# Tools & Technologies
#
# 1. Microsoft Office
#
# Interpersonal Skills
#
# 1. Communication
#
# Show less Show only Tâm’s featured skills
#
# Interests
#
# Ogilvy
#
# 1,095,592 followers
#
# Procter & Gamble
#
# 5,896,130 followers
#
# Unilever
#
# 13,834,228 followers
#
#
#
# VINAMILK - Vietnam Dairy Products Joint Stock Company
#
# 47,809 followers
#
# RMIT University Vietnam
#
# 32,332 followers
#
# Edelman
#
# 401,099 followers
#
# See all See all following
#
# People also viewed
#
# Tấn Phát Phạm 3rd degree connection 3rd
#
# Content Writer at Mango Digital
#
# Connect
#
# file:///in/baotamngh/detail/interests/
#
#
# Tien Nguyen 3rd degree connection 3rd
#
# Content Writer About SEO at Brands Vietnam
#
# Connect
#
# Dung Nguyen 3rd degree connection 3rd
#
# Content Writer at Hello Health Group
#
# Connect
#
# lê thiện tiến 3rd degree connection 3rd
#
# Copy: Uống sáng chưa? | Giao dịch, đừng giao 'dịch' | Thượng hưởng cuộc sống
#
# Connect
#
# Vy Lam 2nd degree connection 2nd
#
# Freelance Content Writer
#
# Connect
#
#  Show more
#
# People you may know
#
# BE BA (My Nguyen) {:distance} {:distance}
#
# Recruitment Specialist cum Admin at Milensea Retail
#
# Connect
#
#
#
# Hien Tran {:distance} {:distance}
#
# IT Recruitment consultant
#
# Connect
#
# Le Nhat Huy {:distance} {:distance}
#
# President at UTE Logistics and Supply Chain Club
#
# Connect
#
# Khánh Linh Đỗ {:distance} {:distance}
#
# Human Resources Assistant at Hachinet Software
#
# Connect
#
# Nguyen Dinh Dat {:distance} {:distance}
#
# Frontend Angular Developer
#
# Connect
#
#  Show more
#
# Duc, learn what hiring managers look for in answers to top interview questions
#
# Tell me about a time you surpassed people’s expectations.
#
# file:///interview-prep/assessments/urn:li:fs_assessment:(1,a)/question/urn:li:fs_assessmentQuestion:(10032,aq32)/
#
#
# Do you have any questions for me?
#
# What is your greatest strength?
#
# See all questions
#
# LinkedIn Footer Content
#
# About
# Accessibility
# Talent Solutions
# Community Guidelines
# Careers
# Marketing Solutions
#
# Privacy & Terms
# Ad Choices
# Advertising
# Sales Solutions
# Mobile
# Small Business
# Safety Center
#
#  Questions?
#
# Visit our Help Center.
#
#  Manage your account and privacy
#
# Go to your Settings.
#
# Select Language ةیبرعلا  (Arabic)
#
# file:///interview-prep/assessments/urn:li:fs_assessment:(1,a)/question/urn:li:fs_assessmentQuestion:(10009,aq9)/
# file:///interview-prep/assessments/urn:li:fs_assessment:(1,a)/question/urn:li:fs_assessmentQuestion:(10024,aq24)/
# file:///interview-prep/
# https://about.linkedin.com
# https://www.linkedin.com/accessibility
# https://business.linkedin.com/talent-solutions?trk=flagship_nav&veh=li-footer-lts-control&src=li-footer
# https://www.linkedin.com/help/linkedin/answer/34593
# https://www.linkedin.com/company/linkedin/life?trk=d_flagship3_nav
# https://business.linkedin.com/marketing-solutions?trk=n_nav_lms_f&src=li-footer
# https://www.linkedin.com/help/linkedin/answer/62931
# https://www.linkedin.com/ad/start?trk=n_nav_ads_f
# https://business.linkedin.com/sales-solutions?trk=flagship_nav&veh=li-footer-lss-control&src=li-footer
# https://mobile.linkedin.com/
# https://smallbusiness.linkedin.com?&src=li-footer
# https://safety.linkedin.com
# https://www.linkedin.com/help/linkedin?trk=d_flagship3_profile_view_base
# https://www.linkedin.com/psettings/
#
#
# LinkedIn Corporation © 2021
#
# Status is offline
#
# Messaging You are on the messaging overlay. Press enter to open the list of conversations.
#
#  Compose message
#
#  You are on the messaging overlay. Press enter to open the list of conversations.
# Marketista Chamba - Oportunidades para Marketeros y Publicistas
# Loading…
#
#
# 	0 notifications total
# 	Primary Navigation
# 	Content Writer at 1PAC Vietnam Co., Ltd
# 	People and pages related to Tâm
# 	About
# 	Featured
# 	Featured
#
# 	Activity
# 	Experience
# 	Content Writer
# 	Dates Employed Feb 2019 – Present
# 	Employment Duration 2 yrs 3 mos
# 	Location Ho Chi Minh City, Vietnam
#
#
# 	Education
# 	RMIT University Vietnam
#
# 	Licenses & certifications
# 	Content Battle
#
# 	Volunteer experience
# 	Community Volunteer
# 	Company Name RMIT University Vietnam
# 	Dates volunteered Dec 2019
# 	Volunteer duration 1 mo
# 	Cause Education
#
#
# 	Skills & endorsements
# 	Tools & Technologies
# 	Interpersonal Skills
#
# 	Interests
# 	Ogilvy
# 	Procter & Gamble
# 	Unilever
# 	VINAMILK - Vietnam Dairy Products Joint Stock Company
# 	RMIT University Vietnam
# 	Edelman
#
# 	People also viewed
# 	Tấn Phát Phạm 3rd degree connection 3rd
# 	Tien Nguyen 3rd degree connection 3rd
# 	Dung Nguyen 3rd degree connection 3rd
# 	lê thiện tiến 3rd degree connection 3rd
# 	Vy Lam 2nd degree connection 2nd
#
# 	People you may know
# 	BE BA (My Nguyen) {:distance} {:distance}
# 	Hien Tran {:distance} {:distance}
# 	Le Nhat Huy {:distance} {:distance}
# 	Khánh Linh Đỗ {:distance} {:distance}
# 	Nguyen Dinh Dat {:distance} {:distance}
#
# 	Duc, learn what hiring managers look for in answers to top interview questions
# 	LinkedIn Footer Content
# 	Messaging You are on the messaging overlay. Press enter to open the list of conversations.
